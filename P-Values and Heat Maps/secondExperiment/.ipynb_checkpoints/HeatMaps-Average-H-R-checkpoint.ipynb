# %% [markdown]
# # DNA Methylation P Values

# %%
import pandas as pd
from scipy.stats import ttest_ind_from_stats
import math
from IPython.display import display, HTML

# %%
#https://www.graphpad.com/quickcalcs/ttest2/

# %%
data_path = "data/DNA_methylation/"
result_path = "result/DNA_methylation/"

# %%
df = pd.read_csv(data_path + "H-R.csv")

# %%
columns1 = ['one','Average1','SD1']
columns2 = ['two','Average2','SD2']
columns3 = ['three','Average3','SD3']
columns4 = ['four','Average4','SD4']

# %%
df.head(10)
# Out:
#              one       Average1   SD1 Unnamed: 3            two  \
# 0  CY1P1A1-RE-T0  CY1P1A1-RE-T0    SD    P value  CY1P1A1-RE-T1
# 1            Air              1  0.23        NaN            Air
# 2         4L/min           1.16  0.68        NaN         4L/min
# 3         1L/min           1.36  0.21        NaN         1L/min
# 4       0.5L/min           1.35  0.11        NaN       0.5L/min
# 5            NaN        Average    SD        NaN            NaN
# 6   ALU-RT-RE-T0   ALU-RT-RE-T0    SD    P value   ALU-RT-RE-T1
# 7            Air              1  0.14        NaN            Air
# 8         4L/min           1.05  0.14        NaN         4L/min
# 9         1L/min           1.21  0.39        NaN         1L/min
#
#         Average2   SD2 Unnamed: 7           three        Average3   SD3  \
# 0  CY1P1A1-RE-T1    SD    P value  CY1P1A1-RE-PT2  CY1P1A1-RE-PT2    SD
# 1              1  0.18        NaN             Air               1  0.29
# 2           0.21  0.11        NaN          4L/min            1.12  0.31
# 3           0.72  0.18        NaN          1L/min            0.98  0.22
# 4           0.69  0.21        NaN        0.5L/min            0.55  0.04
# 5        Average    SD        NaN             NaN         Average    SD
# 6   ALU-RT-RE-T1    SD    P value   ALU-RT-RE-PT2   ALU-RT-RE-PT2    SD
# 7              1  0.26        NaN             Air               1   0.1
# 8           0.71   0.1        NaN          4L/min             0.9  0.34
# 9            0.6  0.12        NaN          1L/min             0.9  0.13
#
#   Unnamed: 11            four        Average4   SD4 Unnamed: 15
# 0    P value   CY1P1A1-RE-PT7  CY1P1A1-RE-PT7    SD     P value
# 1         NaN             Air               1  0.46         NaN
# 2         NaN          4L/min             0.9  0.15         NaN
# 3         NaN          1L/min            1.56  0.04         NaN
# 4         NaN        0.5L/min             0.7  0.22         NaN
# 5         NaN             NaN         Average    SD         NaN
# 6    P value    ALU-RT-RE-PT7   ALU-RT-RE-PT7    SD     P value
# 7         NaN             Air               1   0.3         NaN
# 8         NaN          4L/min             1.1  0.19         NaN
# 9         NaN          1L/min            1.43   0.3         NaN

# %%
def get_p_values(Experiment,cnames):
    n = 3
    p_values=['p-values','NA']
    for i in range(2,5):
        m1 = float(Experiment[cnames[1]][1])
        std1 = float(Experiment[cnames[2]][1])
        m2 = float(Experiment[cnames[1]][i])
        std2 = float(Experiment[cnames[2]][i])
        print("Air : ", "Mean : ", m1 , "SD : " , std1, "N : ", n )
        print(Experiment[cnames[0]][i], "Mean : ", m2 , "SD : " , std2, "N : ", n  )
        tstat, pvalue = ttest_ind_from_stats(m1, std1, n, m2, std2, n)
        print("P-Value : ", pvalue)
        p_values.append(round(pvalue,4))
        print('*'*20)
    Experiment['p_vales']= p_values
    return Experiment.copy()


def get_experiment(data,cnames,result_path,filename):
    HeatMapPvalues = {}
    for i in range(0, len(data), 6):
        Experiment = data.loc[i:i+4,cnames].copy().reset_index(drop = True)
        print("Data : ")
        display(Experiment)
        print("*"*20)
        Result = get_p_values(Experiment,cnames)
        #display(Result)
        geneName = Result[cnames[1]].iloc[0].split('-')[0]
        geneValues = Result[cnames[1]][2:5]
        HeatMapPvalues[geneName] = geneValues
    return HeatMapPvalues

# %%
H1 = get_experiment(df,columns1,result_path,"df-part-1")
H2 = get_experiment(df,columns2,result_path,"df-part-2")
H3 = get_experiment(df,columns3,result_path,"df-part-3")
H4 = get_experiment(df,columns4,result_path,"df-part-4")
# Out:
# Data :
#              one       Average1   SD1
# 0  CY1P1A1-RE-T0  CY1P1A1-RE-T0    SD
# 1            Air              1  0.23
# 2         4L/min           1.16  0.68
# 3         1L/min           1.36  0.21
# 4       0.5L/min           1.35  0.11
# ********************
# Air :  Mean :  1.0 SD :  0.23 N :  3
# 4L/min Mean :  1.16 SD :  0.68 N :  3
# P-Value :  0.719109871632
# ********************
# Air :  Mean :  1.0 SD :  0.23 N :  3
# 1L/min Mean :  1.36 SD :  0.21 N :  3
# P-Value :  0.115843649869
# ********************
# Air :  Mean :  1.0 SD :  0.23 N :  3
# 0.5L/min Mean :  1.35 SD :  0.11 N :  3
# P-Value :  0.0761728664993
# ********************
# Data :
#             one      Average1   SD1
# 0  ALU-RT-RE-T0  ALU-RT-RE-T0    SD
# 1           Air             1  0.14
# 2        4L/min          1.05  0.14
# 3        1L/min          1.21  0.39
# 4      0.5L/min          1.11  0.18
# ********************
# Air :  Mean :  1.0 SD :  0.14 N :  3
# 4L/min Mean :  1.05 SD :  0.14 N :  3
# P-Value :  0.684394863426
# ********************
# Air :  Mean :  1.0 SD :  0.14 N :  3
# 1L/min Mean :  1.21 SD :  0.39 N :  3
# P-Value :  0.429615789525
# ********************
# Air :  Mean :  1.0 SD :  0.14 N :  3
# 0.5L/min Mean :  1.11 SD :  0.18 N :  3
# P-Value :  0.45043181065
# ********************
# Data :
#               one        Average1   SD1
# 0  5 UTR S2-RE-T0  5 UTR S2-RE-T0    SD
# 1             Air               1  0.11
# 2          4L/min            1.19  0.21
# 3          1L/min            1.06  0.12
# 4        0.5L/min               1  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 4L/min Mean :  1.19 SD :  0.21 N :  3
# P-Value :  0.23739440427
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 1L/min Mean :  1.06 SD :  0.12 N :  3
# P-Value :  0.557935846888
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 0.5L/min Mean :  1.0 SD :  0.05 N :  3
# P-Value :  1.0
# ********************
# Data :
#               one        Average1   SD1
# 0  5 UTR S3-RE-T0  5 UTR S3-RE-T0    SD
# 1             Air               1  0.12
# 2          4L/min            0.86  0.29
# 3          1L/min            1.01  0.33
# 4        0.5L/min            1.58  0.49
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 4L/min Mean :  0.86 SD :  0.29 N :  3
# P-Value :  0.482859271634
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 1L/min Mean :  1.01 SD :  0.33 N :  3
# P-Value :  0.963023968675
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 0.5L/min Mean :  1.58 SD :  0.49 N :  3
# P-Value :  0.117271349044
# ********************
# Data :
#                one        Average1   SD1
# 0  HS 5 UTR -RE-T0  HS 5 UTR-RE-T0    SD
# 1              Air               1  0.04
# 2           4L/min            1.08  0.17
# 3           1L/min            1.14  0.18
# 4         0.5L/min            1.04  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4L/min Mean :  1.08 SD :  0.17 N :  3
# P-Value :  0.471944317463
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1L/min Mean :  1.14 SD :  0.18 N :  3
# P-Value :  0.258808218513
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5L/min Mean :  1.04 SD :  0.05 N :  3
# P-Value :  0.340121227733
# ********************
# Data :
#               one        Average1   SD1
# 0  HS 3 UTR-RE-T0  HS 3 UTR-RE-T0    SD
# 1             Air               1  0.31
# 2          4L/min            1.27   0.3
# 3          1L/min            1.47  0.36
# 4        0.5L/min            1.35  0.09
# ********************
# Air :  Mean :  1.0 SD :  0.31 N :  3
# 4L/min Mean :  1.27 SD :  0.3 N :  3
# P-Value :  0.339312384291
# ********************
# Air :  Mean :  1.0 SD :  0.31 N :  3
# 1L/min Mean :  1.47 SD :  0.36 N :  3
# P-Value :  0.161769916436
# ********************
# Air :  Mean :  1.0 SD :  0.31 N :  3
# 0.5L/min Mean :  1.35 SD :  0.09 N :  3
# P-Value :  0.133590169866
# ********************
# Data :
#           one    Average1   SD1
# 0  ORF1-RE-T0  ORF1-RE-T0    SD
# 1         Air           1  0.16
# 2      4L/min         0.7  0.14
# 3      1L/min        0.93  0.17
# 4    0.5L/min        0.57  0.07
# ********************
# Air :  Mean :  1.0 SD :  0.16 N :  3
# 4L/min Mean :  0.7 SD :  0.14 N :  3
# P-Value :  0.0708971143203
# ********************
# Air :  Mean :  1.0 SD :  0.16 N :  3
# 1L/min Mean :  0.93 SD :  0.17 N :  3
# P-Value :  0.630929722612
# ********************
# Air :  Mean :  1.0 SD :  0.16 N :  3
# 0.5L/min Mean :  0.57 SD :  0.07 N :  3
# P-Value :  0.0130057975102
# ********************
# Data :
#           one    Average1   SD1
# 0  ORF2-RE-T0  ORF2-RE-T0    SD
# 1         Air           1  0.23
# 2      4L/min        0.77  0.23
# 3      1L/min        0.66   0.2
# 4    0.5L/min        0.42  0.06
# ********************
# Air :  Mean :  1.0 SD :  0.23 N :  3
# 4L/min Mean :  0.77 SD :  0.23 N :  3
# P-Value :  0.287864134727
# ********************
# Air :  Mean :  1.0 SD :  0.23 N :  3
# 1L/min Mean :  0.66 SD :  0.2 N :  3
# P-Value :  0.125510575828
# ********************
# Air :  Mean :  1.0 SD :  0.23 N :  3
# 0.5L/min Mean :  0.42 SD :  0.06 N :  3
# P-Value :  0.013409295623
# ********************
# Data :
#              two       Average2   SD2
# 0  CY1P1A1-RE-T1  CY1P1A1-RE-T1    SD
# 1            Air              1  0.18
# 2         4L/min           0.21  0.11
# 3         1L/min           0.72  0.18
# 4       0.5L/min           0.69  0.21
# ********************
# Air :  Mean :  1.0 SD :  0.18 N :  3
# 4L/min Mean :  0.21 SD :  0.11 N :  3
# P-Value :  0.00291245288331
# ********************
# Air :  Mean :  1.0 SD :  0.18 N :  3
# 1L/min Mean :  0.72 SD :  0.18 N :  3
# P-Value :  0.129466365894
# ********************
# Air :  Mean :  1.0 SD :  0.18 N :  3
# 0.5L/min Mean :  0.69 SD :  0.21 N :  3
# P-Value :  0.124192403003
# ********************
# Data :
#             two      Average2   SD2
# 0  ALU-RT-RE-T1  ALU-RT-RE-T1    SD
# 1           Air             1  0.26
# 2        4L/min          0.71   0.1
# 3        1L/min           0.6  0.12
# 4      0.5L/min          0.33  0.15
# ********************
# Air :  Mean :  1.0 SD :  0.26 N :  3
# 4L/min Mean :  0.71 SD :  0.1 N :  3
# P-Value :  0.145706295679
# ********************
# Air :  Mean :  1.0 SD :  0.26 N :  3
# 1L/min Mean :  0.6 SD :  0.12 N :  3
# P-Value :  0.0728076441888
# ********************
# Air :  Mean :  1.0 SD :  0.26 N :  3
# 0.5L/min Mean :  0.33 SD :  0.15 N :  3
# P-Value :  0.0180532739995
# ********************
# Data :
#               two        Average2   SD2
# 0  5 UTR S2-RE-T1  5 UTR S2-RE-T1    SD
# 1             Air               1  0.29
# 2          4L/min            0.98  0.13
# 3          1L/min            0.76  0.01
# 4        0.5L/min            0.55  0.27
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 4L/min Mean :  0.98 SD :  0.13 N :  3
# P-Value :  0.918451076793
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 1L/min Mean :  0.76 SD :  0.01 N :  3
# P-Value :  0.225257404984
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 0.5L/min Mean :  0.55 SD :  0.27 N :  3
# P-Value :  0.120571376007
# ********************
# Data :
#               two        Average2   SD2
# 0  5 UTR S3-RE-T1  5 UTR S3-RE-T1    SD
# 1             Air               1   0.4
# 2          4L/min            0.61  0.11
# 3          1L/min            0.55  0.16
# 4        0.5L/min             0.5  0.14
# ********************
# Air :  Mean :  1.0 SD :  0.4 N :  3
# 4L/min Mean :  0.61 SD :  0.11 N :  3
# P-Value :  0.178791870343
# ********************
# Air :  Mean :  1.0 SD :  0.4 N :  3
# 1L/min Mean :  0.55 SD :  0.16 N :  3
# P-Value :  0.144683500799
# ********************
# Air :  Mean :  1.0 SD :  0.4 N :  3
# 0.5L/min Mean :  0.5 SD :  0.14 N :  3
# P-Value :  0.11050150557
# ********************
# Data :
#                two        Average2   SD2
# 0  HS 5 UTR -RE-T1  HS 5 UTR-RE-T1    SD
# 1              Air               1  0.42
# 2           4L/min            0.91  0.32
# 3           1L/min            0.65  0.06
# 4         0.5L/min            0.36  0.31
# ********************
# Air :  Mean :  1.0 SD :  0.42 N :  3
# 4L/min Mean :  0.91 SD :  0.32 N :  3
# P-Value :  0.782510108814
# ********************
# Air :  Mean :  1.0 SD :  0.42 N :  3
# 1L/min Mean :  0.65 SD :  0.06 N :  3
# P-Value :  0.226245218742
# ********************
# Air :  Mean :  1.0 SD :  0.42 N :  3
# 0.5L/min Mean :  0.36 SD :  0.31 N :  3
# P-Value :  0.100940677754
# ********************
# Data :
#               two        Average2   SD2
# 0  HS 3 UTR-RE-T1  HS 3 UTR-RE-T1    SD
# 1             Air               1  0.22
# 2          4L/min            1.01  0.63
# 3          1L/min            0.62  0.05
# 4        0.5L/min            0.66  0.41
# ********************
# Air :  Mean :  1.0 SD :  0.22 N :  3
# 4L/min Mean :  1.01 SD :  0.63 N :  3
# P-Value :  0.980535888026
# ********************
# Air :  Mean :  1.0 SD :  0.22 N :  3
# 1L/min Mean :  0.62 SD :  0.05 N :  3
# P-Value :  0.0433590988101
# ********************
# Air :  Mean :  1.0 SD :  0.22 N :  3
# 0.5L/min Mean :  0.66 SD :  0.41 N :  3
# P-Value :  0.274340609043
# ********************
# Data :
#           two    Average2   SD2
# 0  ORF1-RE-T1  ORF1-RE-T1    SD
# 1         Air           1  0.39
# 2      4L/min        0.81  0.06
# 3      1L/min        0.96  0.19
# 4    0.5L/min        0.29  0.18
# ********************
# Air :  Mean :  1.0 SD :  0.39 N :  3
# 4L/min Mean :  0.81 SD :  0.06 N :  3
# P-Value :  0.451186082641
# ********************
# Air :  Mean :  1.0 SD :  0.39 N :  3
# 1L/min Mean :  0.96 SD :  0.19 N :  3
# P-Value :  0.88085557539
# ********************
# Air :  Mean :  1.0 SD :  0.39 N :  3
# 0.5L/min Mean :  0.29 SD :  0.18 N :  3
# P-Value :  0.0457908236074
# ********************
# Data :
#           two    Average2   SD2
# 0  ORF2-RE-T1  ORF2-RE-T1    SD
# 1         Air           1  0.48
# 2      4L/min        1.04  0.14
# 3      1L/min         0.8   0.1
# 4    0.5L/min        0.38  0.12
# ********************
# Air :  Mean :  1.0 SD :  0.48 N :  3
# 4L/min Mean :  1.04 SD :  0.14 N :  3
# P-Value :  0.896490559371
# ********************
# Air :  Mean :  1.0 SD :  0.48 N :  3
# 1L/min Mean :  0.8 SD :  0.1 N :  3
# P-Value :  0.518847401687
# ********************
# Air :  Mean :  1.0 SD :  0.48 N :  3
# 0.5L/min Mean :  0.38 SD :  0.12 N :  3
# P-Value :  0.0957635836022
# ********************
# Data :
#             three        Average3   SD3
# 0  CY1P1A1-RE-PT2  CY1P1A1-RE-PT2    SD
# 1             Air               1  0.29
# 2          4L/min            1.12  0.31
# 3          1L/min            0.98  0.22
# 4        0.5L/min            0.55  0.04
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 4L/min Mean :  1.12 SD :  0.31 N :  3
# P-Value :  0.650036563498
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 1L/min Mean :  0.98 SD :  0.22 N :  3
# P-Value :  0.928759707041
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 0.5L/min Mean :  0.55 SD :  0.04 N :  3
# P-Value :  0.0562460830976
# ********************
# Data :
#            three       Average3   SD3
# 0  ALU-RT-RE-PT2  ALU-RT-RE-PT2    SD
# 1            Air              1   0.1
# 2         4L/min            0.9  0.34
# 3         1L/min            0.9  0.13
# 4       0.5L/min           0.81  0.14
# ********************
# Air :  Mean :  1.0 SD :  0.1 N :  3
# 4L/min Mean :  0.9 SD :  0.34 N :  3
# P-Value :  0.650620045061
# ********************
# Air :  Mean :  1.0 SD :  0.1 N :  3
# 1L/min Mean :  0.9 SD :  0.13 N :  3
# P-Value :  0.350506349174
# ********************
# Air :  Mean :  1.0 SD :  0.1 N :  3
# 0.5L/min Mean :  0.81 SD :  0.14 N :  3
# P-Value :  0.128331998625
# ********************
# Data :
#              three         Average3   SD3
# 0  5 UTR S2-RE-PT2  5 UTR S2-RE-PT2    SD
# 1              Air                1  0.15
# 2           4L/min             0.75   0.1
# 3           1L/min             0.68   0.3
# 4         0.5L/min             0.72  0.13
# ********************
# Air :  Mean :  1.0 SD :  0.15 N :  3
# 4L/min Mean :  0.75 SD :  0.1 N :  3
# P-Value :  0.0742014823364
# ********************
# Air :  Mean :  1.0 SD :  0.15 N :  3
# 1L/min Mean :  0.68 SD :  0.3 N :  3
# P-Value :  0.173782047091
# ********************
# Air :  Mean :  1.0 SD :  0.15 N :  3
# 0.5L/min Mean :  0.72 SD :  0.13 N :  3
# P-Value :  0.0709582385388
# ********************
# Data :
#              three         Average3   SD3
# 0  5 UTR S3-RE-PT2  5 UTR S3-RE-PT2    SD
# 1              Air                1  0.06
# 2           4L/min             1.35  0.21
# 3           1L/min             0.89  0.04
# 4         0.5L/min             0.76   0.1
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 4L/min Mean :  1.35 SD :  0.21 N :  3
# P-Value :  0.0500391336287
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 1L/min Mean :  0.89 SD :  0.04 N :  3
# P-Value :  0.0574532007151
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 0.5L/min Mean :  0.76 SD :  0.1 N :  3
# P-Value :  0.0234904712217
# ********************
# Data :
#               three         Average3   SD3
# 0  HS 5 UTR -RE-PT2  HS 5 UTR-RE-PT2    SD
# 1               Air                1  0.29
# 2            4L/min              1.1  0.14
# 3            1L/min              1.1  0.15
# 4          0.5L/min             1.11  0.37
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 4L/min Mean :  1.1 SD :  0.14 N :  3
# P-Value :  0.619202354918
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 1L/min Mean :  1.1 SD :  0.15 N :  3
# P-Value :  0.623852985867
# ********************
# Air :  Mean :  1.0 SD :  0.29 N :  3
# 0.5L/min Mean :  1.11 SD :  0.37 N :  3
# P-Value :  0.70601042115
# ********************
# Data :
#              three         Average3   SD3
# 0  HS 3 UTR-RE-PT2  HS 3 UTR-RE-PT2    SD
# 1              Air                1  0.01
# 2           4L/min             0.98  0.18
# 3           1L/min             1.24  0.32
# 4         0.5L/min             1.22   0.1
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 4L/min Mean :  0.98 SD :  0.18 N :  3
# P-Value :  0.856982601635
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 1L/min Mean :  1.24 SD :  0.32 N :  3
# P-Value :  0.263947942724
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 0.5L/min Mean :  1.22 SD :  0.1 N :  3
# P-Value :  0.019242312891
# ********************
# Data :
#          three     Average3   SD3
# 0  ORF1-RE-PT2  ORF1-RE-PT2    SD
# 1          Air            1  0.39
# 2       4L/min         1.05  0.48
# 3       1L/min         0.97  0.01
# 4     0.5L/min         0.74  0.14
# ********************
# Air :  Mean :  1.0 SD :  0.39 N :  3
# 4L/min Mean :  1.05 SD :  0.48 N :  3
# P-Value :  0.895405804487
# ********************
# Air :  Mean :  1.0 SD :  0.39 N :  3
# 1L/min Mean :  0.97 SD :  0.01 N :  3
# P-Value :  0.900474298115
# ********************
# Air :  Mean :  1.0 SD :  0.39 N :  3
# 0.5L/min Mean :  0.74 SD :  0.14 N :  3
# P-Value :  0.338233329213
# ********************
# Data :
#          three     Average3   SD3
# 0  ORF2-RE-PT2  ORF2-RE-PT2    SD
# 1          Air            1  0.35
# 2       4L/min         0.89  0.12
# 3       1L/min         0.64  0.16
# 4     0.5L/min         0.51  0.09
# ********************
# Air :  Mean :  1.0 SD :  0.35 N :  3
# 4L/min Mean :  0.89 SD :  0.12 N :  3
# P-Value :  0.633747152634
# ********************
# Air :  Mean :  1.0 SD :  0.35 N :  3
# 1L/min Mean :  0.64 SD :  0.16 N :  3
# P-Value :  0.180490993939
# ********************
# Air :  Mean :  1.0 SD :  0.35 N :  3
# 0.5L/min Mean :  0.51 SD :  0.09 N :  3
# P-Value :  0.0786466500864
# ********************
# Data :
#              four        Average4   SD4
# 0  CY1P1A1-RE-PT7  CY1P1A1-RE-PT7    SD
# 1             Air               1  0.46
# 2          4L/min             0.9  0.15
# 3          1L/min            1.56  0.04
# 4        0.5L/min             0.7  0.22
# ********************
# Air :  Mean :  1.0 SD :  0.46 N :  3
# 4L/min Mean :  0.9 SD :  0.15 N :  3
# P-Value :  0.738449188431
# ********************
# Air :  Mean :  1.0 SD :  0.46 N :  3
# 1L/min Mean :  1.56 SD :  0.04 N :  3
# P-Value :  0.103576494276
# ********************
# Air :  Mean :  1.0 SD :  0.46 N :  3
# 0.5L/min Mean :  0.7 SD :  0.22 N :  3
# P-Value :  0.365800305735
# ********************
# Data :
#             four       Average4   SD4
# 0  ALU-RT-RE-PT7  ALU-RT-RE-PT7    SD
# 1            Air              1   0.3
# 2         4L/min            1.1  0.19
# 3         1L/min           1.43   0.3
# 4       0.5L/min           1.36  0.23
# ********************
# Air :  Mean :  1.0 SD :  0.3 N :  3
# 4L/min Mean :  1.1 SD :  0.19 N :  3
# P-Value :  0.651249454784
# ********************
# Air :  Mean :  1.0 SD :  0.3 N :  3
# 1L/min Mean :  1.43 SD :  0.3 N :  3
# P-Value :  0.154029601462
# ********************
# Air :  Mean :  1.0 SD :  0.3 N :  3
# 0.5L/min Mean :  1.36 SD :  0.23 N :  3
# P-Value :  0.174394365973
# ********************
# Data :
#               four         Average4   SD4
# 0  5 UTR S2-RE-PT7  5 UTR S2-RE-PT7    SD
# 1              Air                1   0.5
# 2           4L/min             1.13  0.49
# 3           1L/min              0.9  0.09
# 4         0.5L/min             1.02  0.16
# ********************
# Air :  Mean :  1.0 SD :  0.5 N :  3
# 4L/min Mean :  1.13 SD :  0.49 N :  3
# P-Value :  0.763836132893
# ********************
# Air :  Mean :  1.0 SD :  0.5 N :  3
# 1L/min Mean :  0.9 SD :  0.09 N :  3
# P-Value :  0.750310296987
# ********************
# Air :  Mean :  1.0 SD :  0.5 N :  3
# 0.5L/min Mean :  1.02 SD :  0.16 N :  3
# P-Value :  0.950555430776
# ********************
# Data :
#               four         Average4   SD4
# 0  5 UTR S3-RE-PT7  5 UTR S3-RE-PT7    SD
# 1              Air                1  0.41
# 2           4L/min              1.1  0.48
# 3           1L/min             1.57  0.59
# 4         0.5L/min             1.38  0.37
# ********************
# Air :  Mean :  1.0 SD :  0.41 N :  3
# 4L/min Mean :  1.1 SD :  0.48 N :  3
# P-Value :  0.797382767356
# ********************
# Air :  Mean :  1.0 SD :  0.41 N :  3
# 1L/min Mean :  1.57 SD :  0.59 N :  3
# P-Value :  0.24137113124
# ********************
# Air :  Mean :  1.0 SD :  0.41 N :  3
# 0.5L/min Mean :  1.38 SD :  0.37 N :  3
# P-Value :  0.299224252198
# ********************
# Data :
#                four         Average4   SD4
# 0  HS 5 UTR -RE-PT7  HS 5 UTR-RE-PT7    SD
# 1               Air                1  0.21
# 2            4L/min              0.9  0.37
# 3            1L/min             1.12  0.23
# 4          0.5L/min             0.92  0.38
# ********************
# Air :  Mean :  1.0 SD :  0.21 N :  3
# 4L/min Mean :  0.9 SD :  0.37 N :  3
# P-Value :  0.70476502617
# ********************
# Air :  Mean :  1.0 SD :  0.21 N :  3
# 1L/min Mean :  1.12 SD :  0.23 N :  3
# P-Value :  0.541073945506
# ********************
# Air :  Mean :  1.0 SD :  0.21 N :  3
# 0.5L/min Mean :  0.92 SD :  0.38 N :  3
# P-Value :  0.765584562125
# ********************
# Data :
#               four         Average4   SD4
# 0  HS 3 UTR-RE-PT7  HS 3 UTR-RE-PT7    SD
# 1              Air                1  0.89
# 2           4L/min             1.54   0.4
# 3           1L/min             2.25  0.96
# 4         0.5L/min             2.02  0.08
# ********************
# Air :  Mean :  1.0 SD :  0.89 N :  3
# 4L/min Mean :  1.54 SD :  0.4 N :  3
# P-Value :  0.392068894669
# ********************
# Air :  Mean :  1.0 SD :  0.89 N :  3
# 1L/min Mean :  2.25 SD :  0.96 N :  3
# P-Value :  0.173495542219
# ********************
# Air :  Mean :  1.0 SD :  0.89 N :  3
# 0.5L/min Mean :  2.02 SD :  0.08 N :  3
# P-Value :  0.119199825272
# ********************
# Data :
#           four     Average4   SD4
# 0  ORF1-RE-PT7  ORF1-RE-PT7    SD
# 1          Air            1  0.41
# 2       4L/min         1.55  0.71
# 3       1L/min         2.04   0.3
# 4     0.5L/min         1.77  0.16
# ********************
# Air :  Mean :  1.0 SD :  0.41 N :  3
# 4L/min Mean :  1.55 SD :  0.71 N :  3
# P-Value :  0.309874727549
# ********************
# Air :  Mean :  1.0 SD :  0.41 N :  3
# 1L/min Mean :  2.04 SD :  0.3 N :  3
# P-Value :  0.0238910362647
# ********************
# Air :  Mean :  1.0 SD :  0.41 N :  3
# 0.5L/min Mean :  1.77 SD :  0.16 N :  3
# P-Value :  0.0387688935125
# ********************
# Data :
#           four     Average4   SD4
# 0  ORF2-RE-PT7  ORF2-RE-PT7    SD
# 1          Air            1  0.31
# 2       4L/min         1.39  0.48
# 3       1L/min         1.32  0.21
# 4     0.5L/min         1.98  0.15
# ********************
# Air :  Mean :  1.0 SD :  0.31 N :  3
# 4L/min Mean :  1.39 SD :  0.48 N :  3
# P-Value :  0.30260865393
# ********************
# Air :  Mean :  1.0 SD :  0.31 N :  3
# 1L/min Mean :  1.32 SD :  0.21 N :  3
# P-Value :  0.212910349725
# ********************
# Air :  Mean :  1.0 SD :  0.31 N :  3
# 0.5L/min Mean :  1.98 SD :  0.15 N :  3
# P-Value :  0.00787940165794
# ********************

# %%
dfH1 = pd.DataFrame(H1)
dfH2 = pd.DataFrame(H2)
dfH3 = pd.DataFrame(H3)
dfH4 = pd.DataFrame(H4)

# %%
dfH1
# Out:
#   5 UTR S2 5 UTR S3   ALU CY1P1A1 HS 3 UTR HS 5 UTR  ORF1  ORF2
# 2     1.19     0.86  1.05    1.16     1.27     1.08   0.7  0.77
# 3     1.06     1.01  1.21    1.36     1.47     1.14  0.93  0.66
# 4        1     1.58  1.11    1.35     1.35     1.04  0.57  0.42

# %%
dfH2
# Out:
#   5 UTR S2 5 UTR S3   ALU CY1P1A1 HS 3 UTR HS 5 UTR  ORF1  ORF2
# 2     0.98     0.61  0.71    0.21     1.01     0.91  0.81  1.04
# 3     0.76     0.55   0.6    0.72     0.62     0.65  0.96   0.8
# 4     0.55      0.5  0.33    0.69     0.66     0.36  0.29  0.38

# %%
dfH3
# Out:
#   5 UTR S2 5 UTR S3   ALU CY1P1A1 HS 3 UTR HS 5 UTR  ORF1  ORF2
# 2     0.75     1.35   0.9    1.12     0.98      1.1  1.05  0.89
# 3     0.68     0.89   0.9    0.98     1.24      1.1  0.97  0.64
# 4     0.72     0.76  0.81    0.55     1.22     1.11  0.74  0.51

# %%
dfH4
# Out:
#   5 UTR S2 5 UTR S3   ALU CY1P1A1 HS 3 UTR HS 5 UTR  ORF1  ORF2
# 2     1.13      1.1   1.1     0.9     1.54      0.9  1.55  1.39
# 3      0.9     1.57  1.43    1.56     2.25     1.12  2.04  1.32
# 4     1.02     1.38  1.36     0.7     2.02     0.92  1.77  1.98

# %%
#dfH1 = dfH1.drop([0]).copy()
#dfH3 = dfH3.drop([0]).copy()
#dfH5 = dfH5.drop([0]).copy()
#dfH7 = dfH7.drop([0]).copy()

# %%
df1 = dfH1.transpose()
df2 = dfH2.transpose()
df3 = dfH3.transpose()
df4 = dfH4.transpose()

# %%
df1.columns = ['4L/min','1L/min','0.5L/min']
df2.columns = ['4L/min','1L/min','0.5L/min']
df3.columns = ['4L/min','1L/min','0.5L/min']
df4.columns = ['4L/min','1L/min','0.5L/min']

# %%
df1['4L/min'] = pd.to_numeric(df1['4L/min'])
df1['1L/min'] = pd.to_numeric(df1['1L/min'])
df1['0.5L/min'] = pd.to_numeric(df1['0.5L/min'])



df2['4L/min'] = pd.to_numeric(df2['4L/min'])
df2['1L/min'] = pd.to_numeric(df2['1L/min'])
df2['0.5L/min'] = pd.to_numeric(df2['0.5L/min'])



df3['4L/min'] = pd.to_numeric(df3['4L/min'])
df3['1L/min'] = pd.to_numeric(df3['1L/min'])
df3['0.5L/min'] = pd.to_numeric(df3['0.5L/min'])



df4['4L/min'] = pd.to_numeric(df4['4L/min'])
df4['1L/min'] = pd.to_numeric(df4['1L/min'])
df4['0.5L/min'] = pd.to_numeric(df4['0.5L/min'])

# %%
df1.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df2.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df3.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df4.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
#df1 = df1.apply(lambda x: [y if y <=5 else 5 for y in x])
#df2 = df2.apply(lambda x: [y if y <=5 else 5 for y in x])
#df3 = df3.apply(lambda x: [y if y <=5 else 5 for y in x])
#df4 = df4.apply(lambda x: [y if y <=5 else 5 for y in x])

# %%
df1
# Out:
#           4L/min  1L/min  0.5L/min
# 5 UTR S2    1.19    1.06      1.00
# 5 UTR S3    0.86    1.01      1.58
# ALU         1.05    1.21      1.11
# CY1P1A1     1.16    1.36      1.35
# HS 3 UTR    1.27    1.47      1.35
# HS 5 UTR    1.08    1.14      1.04
# ORF1        0.70    0.93      0.57
# ORF2        0.77    0.66      0.42

# %%
df1 = df1.reindex(["CY1P1A1", "ALU", "5 UTR S2","5 UTR S3","HS 5 UTR","HS 3 UTR","ORF1","ORF2"])

# %%
df1
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     1.16    1.36      1.35
# ALU         1.05    1.21      1.11
# 5 UTR S2    1.19    1.06      1.00
# 5 UTR S3    0.86    1.01      1.58
# HS 5 UTR    1.08    1.14      1.04
# HS 3 UTR    1.27    1.47      1.35
# ORF1        0.70    0.93      0.57
# ORF2        0.77    0.66      0.42

# %%
df2 = df2.reindex(["CY1P1A1", "ALU", "5 UTR S2","5 UTR S3","HS 5 UTR","HS 3 UTR","ORF1","ORF2"])

# %%
df2
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     0.21    0.72      0.69
# ALU         0.71    0.60      0.33
# 5 UTR S2    0.98    0.76      0.55
# 5 UTR S3    0.61    0.55      0.50
# HS 5 UTR    0.91    0.65      0.36
# HS 3 UTR    1.01    0.62      0.66
# ORF1        0.81    0.96      0.29
# ORF2        1.04    0.80      0.38

# %%
df3 = df3.reindex(["CY1P1A1", "ALU", "5 UTR S2","5 UTR S3","HS 5 UTR","HS 3 UTR","ORF1","ORF2"])

# %%
df3
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     1.12    0.98      0.55
# ALU         0.90    0.90      0.81
# 5 UTR S2    0.75    0.68      0.72
# 5 UTR S3    1.35    0.89      0.76
# HS 5 UTR    1.10    1.10      1.11
# HS 3 UTR    0.98    1.24      1.22
# ORF1        1.05    0.97      0.74
# ORF2        0.89    0.64      0.51

# %%
df4 = df4.reindex(["CY1P1A1", "ALU", "5 UTR S2","5 UTR S3","HS 5 UTR","HS 3 UTR","ORF1","ORF2"])

# %%
df4
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     0.90    1.56      0.70
# ALU         1.10    1.43      1.36
# 5 UTR S2    1.13    0.90      1.02
# 5 UTR S3    1.10    1.57      1.38
# HS 5 UTR    0.90    1.12      0.92
# HS 3 UTR    1.54    2.25      2.02
# ORF1        1.55    2.04      1.77
# ORF2        1.39    1.32      1.98

# %%
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df1,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("T0")
plt.yticks(rotation=0)
fig.savefig(result_path + "/H-R/T0.png")

# %%
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df2,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("T1")
plt.yticks(rotation=0)
fig.savefig(result_path + "/H-R/T1.png")

# %%
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df3,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("PT2")
plt.yticks(rotation=0)
fig.savefig(result_path + "/H-R/PT2.png")

# %%
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df4,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("PT7")
plt.yticks(rotation=0)
fig.savefig(result_path + "/H-R/PT7.png")
