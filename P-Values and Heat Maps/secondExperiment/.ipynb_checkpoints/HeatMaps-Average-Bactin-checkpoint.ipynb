# %% [markdown]
# # DNA Methylation P Values

# %%
import pandas as pd
from scipy.stats import ttest_ind_from_stats
import math
from IPython.display import display, HTML

# %%
#https://www.graphpad.com/quickcalcs/ttest2/

# %%
data_path = "data/heat_map_from/"
result_path = "result/heat_map_from/"

# %%
df = pd.read_csv(data_path + "B_actin.csv")

# %%
columns1 = ['one','Average1','SD1']
columns2 = ['two','Average2','SD2']
columns3 = ['three','Average3','SD3']
columns4 = ['four','Average4','SD4']

# %%
df.head(10)
# Out:
#                       one    Average1     SD1                     two  \
# 0  Normalized to B actin   CY1P1A1-T0      SD  Normalized to B actin
# 1                     air        1.06    0.41                     air
# 2                  4l/min     1487.71  210.27                  4l/min
# 3                  1l/min     9406.97  128.81                  1l/min
# 4                0.5l/min      7993.7  592.42                0.5l/min
# 5  Normalized to B actin    ALU-RT-T0      SD  Normalized to B actin
# 6                     air           1    0.06                     air
# 7                  4l/min        1.21    0.24                  4l/min
# 8                  1l/min        0.87    0.14                  1l/min
# 9                0.5l/min        0.76    0.03                0.5l/min
#
#      Average2     SD2                   three     Average3     SD3  \
# 0  CY1P1A1-T1      SD  Normalized to B actin   CY1P1A1-PT2      SD
# 1        1.02    0.24                     air         1.09    0.48
# 2       69.46    6.71                  4l/min         2.17    1.26
# 3      887.36  119.04                  1l/min       309.53   59.83
# 4     5465.07  576.85                0.5l/min      1496.78  290.57
# 5   ALU-RT-T1      SD  Normalized to B actin    ALU-RT-PT2      SD
# 6           1     0.1                     air         1.01    0.15
# 7         0.8    0.13                  4l/min         0.58    0.08
# 8        0.68    0.12                  1l/min         0.85    0.29
# 9         0.6    0.05                0.5l/min         0.56    0.07
#
#                      four     Average4   SD4
# 0  Normalized to B actin   CY1P1A1-PT7    SD
# 1                     air         1.04  0.31
# 2                  4l/min         0.93  0.06
# 3                  1l/min         2.26  1.09
# 4                0.5l/min         5.05  1.99
# 5  Normalized to B actin    ALU-RT-PT7    SD
# 6                     air            1  0.09
# 7                  4l/min         0.93  0.25
# 8                  1l/min         0.94  0.22
# 9                0.5l/min         0.77  0.05

# %%
def get_p_values(Experiment,cnames):
    n = 3
    p_values=['p-values','NA']
    for i in range(2,5):
        m1 = float(Experiment[cnames[1]][1])
        std1 = float(Experiment[cnames[2]][1])
        m2 = float(Experiment[cnames[1]][i])
        std2 = float(Experiment[cnames[2]][i])
        print("Air : ", "Mean : ", m1 , "SD : " , std1, "N : ", n )
        print(Experiment[cnames[0]][i], "Mean : ", m2 , "SD : " , std2, "N : ", n  )
        tstat, pvalue = ttest_ind_from_stats(m1, std1, n, m2, std2, n)
        print("P-Value : ", pvalue)
        p_values.append(round(pvalue,4))
        print('*'*20)
    Experiment['p_vales']= p_values
    return Experiment.copy()


def get_experiment(data,cnames,result_path,filename):
    HeatMapPvalues = {}
    for i in range(0, len(data), 5):
        Experiment = data.loc[i:i+4,cnames].copy().reset_index(drop = True)
        print("Data : ")
        display(Experiment)
        print("*"*20)
        Result = get_p_values(Experiment,cnames)
        #display(Result)
        geneName = Result[cnames[1]].iloc[0].split('-')[0]
        geneValues = Result[cnames[1]][2:5]
        HeatMapPvalues[geneName] = geneValues
    return HeatMapPvalues

# %%
H1 = get_experiment(df,columns1,result_path,"df-part-1")
H2 = get_experiment(df,columns2,result_path,"df-part-2")
H3 = get_experiment(df,columns3,result_path,"df-part-3")
H4 = get_experiment(df,columns4,result_path,"df-part-4")
# Out:
# Data :
#                       one    Average1     SD1
# 0  Normalized to B actin   CY1P1A1-T0      SD
# 1                     air        1.06    0.41
# 2                  4l/min     1487.71  210.27
# 3                  1l/min     9406.97  128.81
# 4                0.5l/min      7993.7  592.42
# ********************
# Air :  Mean :  1.06 SD :  0.41 N :  3
# 4l/min Mean :  1487.71 SD :  210.27 N :  3
# P-Value :  0.000255341900059
# ********************
# Air :  Mean :  1.06 SD :  0.41 N :  3
# 1l/min Mean :  9406.97 SD :  128.81 N :  3
# P-Value :  2.34385968933e-08
# ********************
# Air :  Mean :  1.06 SD :  0.41 N :  3
# 0.5l/min Mean :  7993.7 SD :  592.42 N :  3
# P-Value :  1.98784894891e-05
# ********************
# Data :
#                       one   Average1   SD1
# 0  Normalized to B actin   ALU-RT-T0    SD
# 1                     air          1  0.06
# 2                  4l/min       1.21  0.24
# 3                  1l/min       0.87  0.14
# 4                0.5l/min       0.76  0.03
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 4l/min Mean :  1.21 SD :  0.24 N :  3
# P-Value :  0.215431954178
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 1l/min Mean :  0.87 SD :  0.14 N :  3
# P-Value :  0.213405160628
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 0.5l/min Mean :  0.76 SD :  0.03 N :  3
# P-Value :  0.00344838473909
# ********************
# Data :
#                       one     Average1   SD1
# 0  Normalized to B actin   HS 5 UTR-T0    SD
# 1                     air            1  0.09
# 2                  4l/min         1.01  0.15
# 3                  1l/min         0.85  0.13
# 4                0.5l/min         0.58  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 4l/min Mean :  1.01 SD :  0.15 N :  3
# P-Value :  0.925890221967
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 1l/min Mean :  0.85 SD :  0.13 N :  3
# P-Value :  0.175693108631
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 0.5l/min Mean :  0.58 SD :  0.05 N :  3
# P-Value :  0.00211663574189
# ********************
# Data :
#                       one     Average1   SD1
# 0  Normalized to B actin   HS 3 UTR-T0    SD
# 1                     air            1  0.04
# 2                  4l/min         1.08  0.22
# 3                  1l/min         0.84  0.11
# 4                0.5l/min         0.63  0.15
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4l/min Mean :  1.08 SD :  0.22 N :  3
# P-Value :  0.569024410562
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1l/min Mean :  0.84 SD :  0.11 N :  3
# P-Value :  0.0770165783715
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5l/min Mean :  0.63 SD :  0.15 N :  3
# P-Value :  0.0145159285898
# ********************
# Data :
#                       one Average1   SD1
# 0  Normalized to B actin   ORF1-T0    SD
# 1                     air     1.01  0.14
# 2                  4l/min     1.18   0.2
# 3                  1l/min     0.94  0.15
# 4                0.5l/min     0.67  0.08
# ********************
# Air :  Mean :  1.01 SD :  0.14 N :  3
# 4l/min Mean :  1.18 SD :  0.2 N :  3
# P-Value :  0.294234527872
# ********************
# Air :  Mean :  1.01 SD :  0.14 N :  3
# 1l/min Mean :  0.94 SD :  0.15 N :  3
# P-Value :  0.586357542482
# ********************
# Air :  Mean :  1.01 SD :  0.14 N :  3
# 0.5l/min Mean :  0.67 SD :  0.08 N :  3
# P-Value :  0.0217295115009
# ********************
# Data :
#                       one Average1   SD1
# 0  Normalized to B actin   ORF2-T0    SD
# 1                     air        1  0.06
# 2                  4l/min     1.18  0.25
# 3                  1l/min     0.91  0.14
# 4                0.5l/min     0.67  0.11
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 4l/min Mean :  1.18 SD :  0.25 N :  3
# P-Value :  0.29198642386
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 1l/min Mean :  0.91 SD :  0.14 N :  3
# P-Value :  0.36395835638
# ********************
# Air :  Mean :  1.0 SD :  0.06 N :  3
# 0.5l/min Mean :  0.67 SD :  0.11 N :  3
# P-Value :  0.0103256831801
# ********************
# Data :
#                       one  Average1   SD1
# 0  Normalized to B actin   DNMT1-T0    SD
# 1                     air         1  0.04
# 2                  4l/min      0.97  0.12
# 3                  1l/min       0.9  0.03
# 4                0.5l/min      0.69  0.01
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4l/min Mean :  0.97 SD :  0.12 N :  3
# P-Value :  0.702278441416
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1l/min Mean :  0.9 SD :  0.03 N :  3
# P-Value :  0.0257214207425
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5l/min Mean :  0.69 SD :  0.01 N :  3
# P-Value :  0.000200667632062
# ********************
# Data :
#                       one   Average1   SD1
# 0  Normalized to B actin   DNMT3A-T0    SD
# 1                     air          1  0.04
# 2                  4l/min       1.04   0.1
# 3                  1l/min       0.92  0.02
# 4                0.5l/min       0.64  0.19
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4l/min Mean :  1.04 SD :  0.1 N :  3
# P-Value :  0.55507315219
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1l/min Mean :  0.92 SD :  0.02 N :  3
# P-Value :  0.0362778245219
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5l/min Mean :  0.64 SD :  0.19 N :  3
# P-Value :  0.0325459825593
# ********************
# Data :
#                       one   Average1   SD1
# 0  Normalized to B actin   DNMT3B-T0    SD
# 1                     air          1  0.05
# 2                  4l/min       1.09  0.18
# 3                  1l/min       0.83  0.06
# 4                0.5l/min       0.52  0.06
# ********************
# Air :  Mean :  1.0 SD :  0.05 N :  3
# 4l/min Mean :  1.09 SD :  0.18 N :  3
# P-Value :  0.450973358818
# ********************
# Air :  Mean :  1.0 SD :  0.05 N :  3
# 1l/min Mean :  0.83 SD :  0.06 N :  3
# P-Value :  0.0196039858832
# ********************
# Air :  Mean :  1.0 SD :  0.05 N :  3
# 0.5l/min Mean :  0.52 SD :  0.06 N :  3
# P-Value :  0.000441036243774
# ********************
# Data :
#                       one Average1   SD1
# 0  Normalized to B actin   TET1-T0    SD
# 1                     air        1  0.15
# 2                  4l/min     1.44  0.37
# 3                  1l/min     0.69  0.25
# 4                0.5l/min     0.21   0.1
# ********************
# Air :  Mean :  1.0 SD :  0.15 N :  3
# 4l/min Mean :  1.44 SD :  0.37 N :  3
# P-Value :  0.128918392009
# ********************
# Air :  Mean :  1.0 SD :  0.15 N :  3
# 1l/min Mean :  0.69 SD :  0.25 N :  3
# P-Value :  0.139327630447
# ********************
# Air :  Mean :  1.0 SD :  0.15 N :  3
# 0.5l/min Mean :  0.21 SD :  0.1 N :  3
# P-Value :  0.00161625331612
# ********************
# Data :
#                       one Average1   SD1
# 0  Normalized to B actin   TET2-T0    SD
# 1                     air        1  0.01
# 2                  4l/min     0.98  0.16
# 3                  1l/min     0.86  0.03
# 4                0.5l/min     0.64  0.04
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 4l/min Mean :  0.98 SD :  0.16 N :  3
# P-Value :  0.839493868136
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 1l/min Mean :  0.86 SD :  0.03 N :  3
# P-Value :  0.00155486933689
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 0.5l/min Mean :  0.64 SD :  0.04 N :  3
# P-Value :  0.000111440229906
# ********************
# Data :
#                       one Average1   SD1
# 0  Normalized to B actin   TET3-T0    SD
# 1                     air        1  0.04
# 2                  4l/min     0.92   0.1
# 3                  1l/min     0.86  0.06
# 4                0.5l/min      0.8  0.03
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4l/min Mean :  0.92 SD :  0.1 N :  3
# P-Value :  0.267668321112
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1l/min Mean :  0.86 SD :  0.06 N :  3
# P-Value :  0.0282342888553
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5l/min Mean :  0.8 SD :  0.03 N :  3
# P-Value :  0.00227842629138
# ********************
# Data :
#                       two    Average2     SD2
# 0  Normalized to B actin   CY1P1A1-T1      SD
# 1                     air        1.02    0.24
# 2                  4l/min       69.46    6.71
# 3                  1l/min      887.36  119.04
# 4                0.5l/min     5465.07  576.85
# ********************
# Air :  Mean :  1.02 SD :  0.24 N :  3
# 4l/min Mean :  69.46 SD :  6.71 N :  3
# P-Value :  6.0455707626e-05
# ********************
# Air :  Mean :  1.02 SD :  0.24 N :  3
# 1l/min Mean :  887.36 SD :  119.04 N :  3
# P-Value :  0.000208483491455
# ********************
# Air :  Mean :  1.02 SD :  0.24 N :  3
# 0.5l/min Mean :  5465.07 SD :  576.85 N :  3
# P-Value :  8.08018384602e-05
# ********************
# Data :
#                       two   Average2   SD2
# 0  Normalized to B actin   ALU-RT-T1    SD
# 1                     air          1   0.1
# 2                  4l/min        0.8  0.13
# 3                  1l/min       0.68  0.12
# 4                0.5l/min        0.6  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.1 N :  3
# 4l/min Mean :  0.8 SD :  0.13 N :  3
# P-Value :  0.10224810703
# ********************
# Air :  Mean :  1.0 SD :  0.1 N :  3
# 1l/min Mean :  0.68 SD :  0.12 N :  3
# P-Value :  0.0238357559702
# ********************
# Air :  Mean :  1.0 SD :  0.1 N :  3
# 0.5l/min Mean :  0.6 SD :  0.05 N :  3
# P-Value :  0.00344838473909
# ********************
# Data :
#                       two     Average2   SD2
# 0  Normalized to B actin   HS 5 UTR-T1    SD
# 1                     air            1  0.13
# 2                  4l/min         0.83  0.12
# 3                  1l/min          0.7  0.14
# 4                0.5l/min         0.56  0.03
# ********************
# Air :  Mean :  1.0 SD :  0.13 N :  3
# 4l/min Mean :  0.83 SD :  0.12 N :  3
# P-Value :  0.171379902668
# ********************
# Air :  Mean :  1.0 SD :  0.13 N :  3
# 1l/min Mean :  0.7 SD :  0.14 N :  3
# P-Value :  0.0529983291323
# ********************
# Air :  Mean :  1.0 SD :  0.13 N :  3
# 0.5l/min Mean :  0.56 SD :  0.03 N :  3
# P-Value :  0.00464551369243
# ********************
# Data :
#                       two     Average2   SD2
# 0  Normalized to B actin   HS 3 UTR-T1    SD
# 1                     air            1  0.07
# 2                  4l/min         0.81  0.11
# 3                  1l/min         0.66  0.12
# 4                0.5l/min         0.57  0.03
# ********************
# Air :  Mean :  1.0 SD :  0.07 N :  3
# 4l/min Mean :  0.81 SD :  0.11 N :  3
# P-Value :  0.0650787467784
# ********************
# Air :  Mean :  1.0 SD :  0.07 N :  3
# 1l/min Mean :  0.66 SD :  0.12 N :  3
# P-Value :  0.0132744179695
# ********************
# Air :  Mean :  1.0 SD :  0.07 N :  3
# 0.5l/min Mean :  0.57 SD :  0.03 N :  3
# P-Value :  0.000612643734722
# ********************
# Data :
#                       two Average2   SD2
# 0  Normalized to B actin   ORF1-T1    SD
# 1                     air        1  0.09
# 2                  4l/min     0.84   0.1
# 3                  1l/min     0.71  0.14
# 4                0.5l/min     0.56  0.04
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 4l/min Mean :  0.84 SD :  0.1 N :  3
# P-Value :  0.108467652911
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 1l/min Mean :  0.71 SD :  0.14 N :  3
# P-Value :  0.0392404408168
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 0.5l/min Mean :  0.56 SD :  0.04 N :  3
# P-Value :  0.00150234702638
# ********************
# Data :
#                       two Average2   SD2
# 0  Normalized to B actin   ORF2-T1    SD
# 1                     air        1  0.09
# 2                  4l/min     0.82  0.16
# 3                  1l/min      0.7  0.14
# 4                0.5l/min     0.57  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 4l/min Mean :  0.82 SD :  0.16 N :  3
# P-Value :  0.164679862813
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 1l/min Mean :  0.7 SD :  0.14 N :  3
# P-Value :  0.0354558002662
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 0.5l/min Mean :  0.57 SD :  0.05 N :  3
# P-Value :  0.00193753578379
# ********************
# Data :
#                       two  Average2   SD2
# 0  Normalized to B actin   DNMT1-T1    SD
# 1                     air         1  0.04
# 2                  4l/min      0.93  0.06
# 3                  1l/min      0.85  0.02
# 4                0.5l/min      0.89  0.01
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4l/min Mean :  0.93 SD :  0.06 N :  3
# P-Value :  0.167989468978
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1l/min Mean :  0.85 SD :  0.02 N :  3
# P-Value :  0.0043685935956
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5l/min Mean :  0.89 SD :  0.01 N :  3
# P-Value :  0.00987423882938
# ********************
# Data :
#                       two   Average2   SD2
# 0  Normalized to B actin   DNMT3A-T1    SD
# 1                     air          1  0.04
# 2                  4l/min       0.95  0.09
# 3                  1l/min       0.83  0.05
# 4                0.5l/min       0.88  0.01
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 4l/min Mean :  0.95 SD :  0.09 N :  3
# P-Value :  0.428883753439
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 1l/min Mean :  0.83 SD :  0.05 N :  3
# P-Value :  0.0100421241049
# ********************
# Air :  Mean :  1.0 SD :  0.04 N :  3
# 0.5l/min Mean :  0.88 SD :  0.01 N :  3
# P-Value :  0.00727690870011
# ********************
# Data :
#                       two   Average2   SD2
# 0  Normalized to B actin   DNMT3B-T1    SD
# 1                     air       1.01  0.13
# 2                  4l/min       0.93  0.03
# 3                  1l/min       0.75  0.02
# 4                0.5l/min       0.86  0.13
# ********************
# Air :  Mean :  1.01 SD :  0.13 N :  3
# 4l/min Mean :  0.93 SD :  0.03 N :  3
# P-Value :  0.357654754737
# ********************
# Air :  Mean :  1.01 SD :  0.13 N :  3
# 1l/min Mean :  0.75 SD :  0.02 N :  3
# P-Value :  0.0266864492319
# ********************
# Air :  Mean :  1.01 SD :  0.13 N :  3
# 0.5l/min Mean :  0.86 SD :  0.13 N :  3
# P-Value :  0.230484611587
# ********************
# Data :
#                       two Average2   SD2
# 0  Normalized to B actin   TET1-T1    SD
# 1                     air     1.01  0.15
# 2                  4l/min     0.69  0.02
# 3                  1l/min     0.45  0.11
# 4                0.5l/min     0.35  0.05
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 4l/min Mean :  0.69 SD :  0.02 N :  3
# P-Value :  0.021530394496
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 1l/min Mean :  0.45 SD :  0.11 N :  3
# P-Value :  0.00645181758968
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 0.5l/min Mean :  0.35 SD :  0.05 N :  3
# P-Value :  0.0019415952834
# ********************
# Data :
#                       two Average2   SD2
# 0  Normalized to B actin   TET2-T1    SD
# 1                     air        1  0.01
# 2                  4l/min     0.89  0.16
# 3                  1l/min     0.78  0.01
# 4                0.5l/min     0.82  0.04
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 4l/min Mean :  0.89 SD :  0.16 N :  3
# P-Value :  0.300387440216
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 1l/min Mean :  0.78 SD :  0.01 N :  3
# P-Value :  1.12797763285e-05
# ********************
# Air :  Mean :  1.0 SD :  0.01 N :  3
# 0.5l/min Mean :  0.82 SD :  0.04 N :  3
# P-Value :  0.00163946550983
# ********************
# Data :
#                       two Average2   SD2
# 0  Normalized to B actin   TET3-T1    SD
# 1                     air        1  0.07
# 2                  4l/min     1.03  0.12
# 3                  1l/min     0.85  0.08
# 4                0.5l/min     0.78   0.1
# ********************
# Air :  Mean :  1.0 SD :  0.07 N :  3
# 4l/min Mean :  1.03 SD :  0.12 N :  3
# P-Value :  0.727365969861
# ********************
# Air :  Mean :  1.0 SD :  0.07 N :  3
# 1l/min Mean :  0.85 SD :  0.08 N :  3
# P-Value :  0.0708971143203
# ********************
# Air :  Mean :  1.0 SD :  0.07 N :  3
# 0.5l/min Mean :  0.78 SD :  0.1 N :  3
# P-Value :  0.0354685622824
# ********************
# Data :
#                     three     Average3     SD3
# 0  Normalized to B actin   CY1P1A1-PT2      SD
# 1                     air         1.09    0.48
# 2                  4l/min         2.17    1.26
# 3                  1l/min       309.53   59.83
# 4                0.5l/min      1496.78  290.57
# ********************
# Air :  Mean :  1.09 SD :  0.48 N :  3
# 4l/min Mean :  2.17 SD :  1.26 N :  3
# P-Value :  0.237626427852
# ********************
# Air :  Mean :  1.09 SD :  0.48 N :  3
# 1l/min Mean :  309.53 SD :  59.83 N :  3
# P-Value :  0.000869936301796
# ********************
# Air :  Mean :  1.09 SD :  0.48 N :  3
# 0.5l/min Mean :  1496.78 SD :  290.57 N :  3
# P-Value :  0.000874931289771
# ********************
# Data :
#                     three    Average3   SD3
# 0  Normalized to B actin   ALU-RT-PT2    SD
# 1                     air        1.01  0.15
# 2                  4l/min        0.58  0.08
# 3                  1l/min        0.85  0.29
# 4                0.5l/min        0.56  0.07
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 4l/min Mean :  0.58 SD :  0.08 N :  3
# P-Value :  0.0118649942907
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 1l/min Mean :  0.85 SD :  0.29 N :  3
# P-Value :  0.44380735883
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 0.5l/min Mean :  0.56 SD :  0.07 N :  3
# P-Value :  0.0092488198754
# ********************
# Data :
#                     three      Average3   SD3
# 0  Normalized to B actin   HS 5 UTR-PT2    SD
# 1                     air          1.01  0.15
# 2                  4l/min          0.77  0.11
# 3                  1l/min          0.95  0.16
# 4                0.5l/min          0.73  0.14
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 4l/min Mean :  0.77 SD :  0.11 N :  3
# P-Value :  0.0891371387936
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 1l/min Mean :  0.95 SD :  0.16 N :  3
# P-Value :  0.660313632122
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 0.5l/min Mean :  0.73 SD :  0.14 N :  3
# P-Value :  0.0773569422374
# ********************
# Data :
#                     three      Average3   SD3
# 0  Normalized to B actin   HS 3 UTR-PT2    SD
# 1                     air             1  0.12
# 2                  4l/min          0.72  0.11
# 3                  1l/min          0.87  0.16
# 4                0.5l/min          0.67  0.08
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 4l/min Mean :  0.72 SD :  0.11 N :  3
# P-Value :  0.0407722263711
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 1l/min Mean :  0.87 SD :  0.16 N :  3
# P-Value :  0.323212688298
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 0.5l/min Mean :  0.67 SD :  0.08 N :  3
# P-Value :  0.01663342038
# ********************
# Data :
#                     three  Average3   SD3
# 0  Normalized to B actin   ORF1-PT2    SD
# 1                     air      1.01   0.1
# 2                  4l/min      0.85  0.08
# 3                  1l/min      0.89  0.12
# 4                0.5l/min      0.71  0.14
# ********************
# Air :  Mean :  1.01 SD :  0.1 N :  3
# 4l/min Mean :  0.85 SD :  0.08 N :  3
# P-Value :  0.0964551228879
# ********************
# Air :  Mean :  1.01 SD :  0.1 N :  3
# 1l/min Mean :  0.89 SD :  0.12 N :  3
# P-Value :  0.254107527674
# ********************
# Air :  Mean :  1.01 SD :  0.1 N :  3
# 0.5l/min Mean :  0.71 SD :  0.14 N :  3
# P-Value :  0.0391554567334
# ********************
# Data :
#                     three  Average3   SD3
# 0  Normalized to B actin   ORF2-PT2    SD
# 1                     air      1.01  0.15
# 2                  4l/min      0.89  0.18
# 3                  1l/min      0.93  0.14
# 4                0.5l/min      0.77   0.1
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 4l/min Mean :  0.89 SD :  0.18 N :  3
# P-Value :  0.42516039454
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 1l/min Mean :  0.93 SD :  0.14 N :  3
# P-Value :  0.536498850355
# ********************
# Air :  Mean :  1.01 SD :  0.15 N :  3
# 0.5l/min Mean :  0.77 SD :  0.1 N :  3
# P-Value :  0.0824076424959
# ********************
# Data :
#                     three   Average3   SD3
# 0  Normalized to B actin   DNMT1-PT2    SD
# 1                     air          1  0.08
# 2                  4l/min       0.81   0.1
# 3                  1l/min       0.78  0.09
# 4                0.5l/min       0.72  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 4l/min Mean :  0.81 SD :  0.1 N :  3
# P-Value :  0.0619946143386
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 1l/min Mean :  0.78 SD :  0.09 N :  3
# P-Value :  0.0340381642907
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 0.5l/min Mean :  0.72 SD :  0.05 N :  3
# P-Value :  0.00678791452689
# ********************
# Data :
#                     three    Average3   SD3
# 0  Normalized to B actin   DNMT3A-PT2    SD
# 1                     air           1  0.05
# 2                  4l/min        0.89  0.06
# 3                  1l/min        0.97  0.06
# 4                0.5l/min        0.94  0.12
# ********************
# Air :  Mean :  1.0 SD :  0.05 N :  3
# 4l/min Mean :  0.89 SD :  0.06 N :  3
# P-Value :  0.0712521867374
# ********************
# Air :  Mean :  1.0 SD :  0.05 N :  3
# 1l/min Mean :  0.97 SD :  0.06 N :  3
# P-Value :  0.54225828109
# ********************
# Air :  Mean :  1.0 SD :  0.05 N :  3
# 0.5l/min Mean :  0.94 SD :  0.12 N :  3
# P-Value :  0.468833544253
# ********************
# Data :
#                     three    Average3   SD3
# 0  Normalized to B actin   DNMT3B-PT2    SD
# 1                     air           1  0.08
# 2                  4l/min        0.81  0.07
# 3                  1l/min        0.99   0.1
# 4                0.5l/min        0.92   0.1
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 4l/min Mean :  0.81 SD :  0.07 N :  3
# P-Value :  0.0363684413846
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 1l/min Mean :  0.99 SD :  0.1 N :  3
# P-Value :  0.898946895985
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 0.5l/min Mean :  0.92 SD :  0.1 N :  3
# P-Value :  0.340121227733
# ********************
# Data :
#                     three  Average3   SD3
# 0  Normalized to B actin   TET1-PT2    SD
# 1                     air      1.01  0.18
# 2                  4l/min      0.79  0.06
# 3                  1l/min      0.72  0.04
# 4                0.5l/min      0.47  0.06
# ********************
# Air :  Mean :  1.01 SD :  0.18 N :  3
# 4l/min Mean :  0.79 SD :  0.06 N :  3
# P-Value :  0.115019672194
# ********************
# Air :  Mean :  1.01 SD :  0.18 N :  3
# 1l/min Mean :  0.72 SD :  0.04 N :  3
# P-Value :  0.052764407815
# ********************
# Air :  Mean :  1.01 SD :  0.18 N :  3
# 0.5l/min Mean :  0.47 SD :  0.06 N :  3
# P-Value :  0.00787564261316
# ********************
# Data :
#                     three  Average3   SD3
# 0  Normalized to B actin   TET2-PT2    SD
# 1                     air         1  0.11
# 2                  4l/min      0.87  0.06
# 3                  1l/min      0.92  0.02
# 4                0.5l/min      0.85  0.06
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 4l/min Mean :  0.87 SD :  0.06 N :  3
# P-Value :  0.146745528584
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 1l/min Mean :  0.92 SD :  0.02 N :  3
# P-Value :  0.282961664179
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 0.5l/min Mean :  0.85 SD :  0.06 N :  3
# P-Value :  0.106807057733
# ********************
# Data :
#                     three  Average3   SD3
# 0  Normalized to B actin   TET3-PT2    SD
# 1                     air         1  0.11
# 2                  4l/min      0.98  0.13
# 3                  1l/min      0.94  0.08
# 4                0.5l/min      0.98  0.09
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 4l/min Mean :  0.98 SD :  0.13 N :  3
# P-Value :  0.848736791781
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 1l/min Mean :  0.94 SD :  0.08 N :  3
# P-Value :  0.487415596542
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 0.5l/min Mean :  0.98 SD :  0.09 N :  3
# P-Value :  0.819427644931
# ********************
# Data :
#                      four     Average4   SD4
# 0  Normalized to B actin   CY1P1A1-PT7    SD
# 1                     air         1.04  0.31
# 2                  4l/min         0.93  0.06
# 3                  1l/min         2.26  1.09
# 4                0.5l/min         5.05  1.99
# ********************
# Air :  Mean :  1.04 SD :  0.31 N :  3
# 4l/min Mean :  0.93 SD :  0.06 N :  3
# P-Value :  0.578787438819
# ********************
# Air :  Mean :  1.04 SD :  0.31 N :  3
# 1l/min Mean :  2.26 SD :  1.09 N :  3
# P-Value :  0.135663689729
# ********************
# Air :  Mean :  1.04 SD :  0.31 N :  3
# 0.5l/min Mean :  5.05 SD :  1.99 N :  3
# P-Value :  0.0260873353492
# ********************
# Data :
#                      four    Average4   SD4
# 0  Normalized to B actin   ALU-RT-PT7    SD
# 1                     air           1  0.09
# 2                  4l/min        0.93  0.25
# 3                  1l/min        0.94  0.22
# 4                0.5l/min        0.77  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 4l/min Mean :  0.93 SD :  0.25 N :  3
# P-Value :  0.671847165206
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 1l/min Mean :  0.94 SD :  0.22 N :  3
# P-Value :  0.684529222738
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 0.5l/min Mean :  0.77 SD :  0.05 N :  3
# P-Value :  0.0180037706802
# ********************
# Data :
#                      four      Average4   SD4
# 0  Normalized to B actin   HS 5 UTR-PT7    SD
# 1                     air             1  0.09
# 2                  4l/min          1.06  0.21
# 3                  1l/min          0.97   0.2
# 4                0.5l/min          0.89  0.02
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 4l/min Mean :  1.06 SD :  0.21 N :  3
# P-Value :  0.672803699741
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 1l/min Mean :  0.97 SD :  0.2 N :  3
# P-Value :  0.824354728558
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 0.5l/min Mean :  0.89 SD :  0.02 N :  3
# P-Value :  0.107651354643
# ********************
# Data :
#                      four      Average4   SD4
# 0  Normalized to B actin   HS 3 UTR-PT7    SD
# 1                     air             1  0.08
# 2                  4l/min          1.07  0.31
# 3                  1l/min          0.94  0.21
# 4                0.5l/min          0.88  0.02
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 4l/min Mean :  1.07 SD :  0.31 N :  3
# P-Value :  0.724152552795
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 1l/min Mean :  0.94 SD :  0.21 N :  3
# P-Value :  0.667794069192
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 0.5l/min Mean :  0.88 SD :  0.02 N :  3
# P-Value :  0.0653216768288
# ********************
# Data :
#                      four  Average4   SD4
# 0  Normalized to B actin   ORF1-PT7    SD
# 1                     air         1  0.03
# 2                  4l/min      1.11  0.34
# 3                  1l/min      0.93  0.18
# 4                0.5l/min      0.81  0.05
# ********************
# Air :  Mean :  1.0 SD :  0.03 N :  3
# 4l/min Mean :  1.11 SD :  0.34 N :  3
# P-Value :  0.606474289905
# ********************
# Air :  Mean :  1.0 SD :  0.03 N :  3
# 1l/min Mean :  0.93 SD :  0.18 N :  3
# P-Value :  0.542771068499
# ********************
# Air :  Mean :  1.0 SD :  0.03 N :  3
# 0.5l/min Mean :  0.81 SD :  0.05 N :  3
# P-Value :  0.00485304884472
# ********************
# Data :
#                      four  Average4   SD4
# 0  Normalized to B actin   ORF2-PT7    SD
# 1                     air         1  0.11
# 2                  4l/min      1.08   0.3
# 3                  1l/min      1.03  0.22
# 4                0.5l/min      0.96  0.06
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 4l/min Mean :  1.08 SD :  0.3 N :  3
# P-Value :  0.686906759816
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 1l/min Mean :  1.03 SD :  0.22 N :  3
# P-Value :  0.843015820152
# ********************
# Air :  Mean :  1.0 SD :  0.11 N :  3
# 0.5l/min Mean :  0.96 SD :  0.06 N :  3
# P-Value :  0.609756417958
# ********************
# Data :
#                      four   Average4   SD4
# 0  Normalized to B actin   DNMT1-PT7    SD
# 1                     air          1  0.09
# 2                  4l/min       0.97  0.06
# 3                  1l/min       0.83  0.13
# 4                0.5l/min       0.85  0.08
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 4l/min Mean :  0.97 SD :  0.06 N :  3
# P-Value :  0.656045011943
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 1l/min Mean :  0.83 SD :  0.13 N :  3
# P-Value :  0.136044587496
# ********************
# Air :  Mean :  1.0 SD :  0.09 N :  3
# 0.5l/min Mean :  0.85 SD :  0.08 N :  3
# P-Value :  0.0971517066201
# ********************
# Data :
#                      four    Average4   SD4
# 0  Normalized to B actin   DNMT3A-PT7    SD
# 1                     air           1  0.08
# 2                  4l/min        1.08  0.15
# 3                  1l/min        0.99  0.09
# 4                0.5l/min        1.09  0.02
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 4l/min Mean :  1.08 SD :  0.15 N :  3
# P-Value :  0.46077246745
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 1l/min Mean :  0.99 SD :  0.09 N :  3
# P-Value :  0.892583242407
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 0.5l/min Mean :  1.09 SD :  0.02 N :  3
# P-Value :  0.131693040722
# ********************
# Data :
#                      four    Average4   SD4
# 0  Normalized to B actin   DNMT3B-PT7    SD
# 1                     air           1  0.12
# 2                  4l/min        1.04   0.1
# 3                  1l/min        0.94  0.18
# 4                0.5l/min        0.86  0.02
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 4l/min Mean :  1.04 SD :  0.1 N :  3
# P-Value :  0.680314841181
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 1l/min Mean :  0.94 SD :  0.18 N :  3
# P-Value :  0.656045011943
# ********************
# Air :  Mean :  1.0 SD :  0.12 N :  3
# 0.5l/min Mean :  0.86 SD :  0.02 N :  3
# P-Value :  0.117017676337
# ********************
# Data :
#                      four  Average4   SD4
# 0  Normalized to B actin   TET1-PT7    SD
# 1                     air      1.01  0.14
# 2                  4l/min      0.99  0.12
# 3                  1l/min      0.93  0.12
# 4                0.5l/min      0.93  0.17
# ********************
# Air :  Mean :  1.01 SD :  0.14 N :  3
# 4l/min Mean :  0.99 SD :  0.12 N :  3
# P-Value :  0.860126058695
# ********************
# Air :  Mean :  1.01 SD :  0.14 N :  3
# 1l/min Mean :  0.93 SD :  0.12 N :  3
# P-Value :  0.494166918007
# ********************
# Air :  Mean :  1.01 SD :  0.14 N :  3
# 0.5l/min Mean :  0.93 SD :  0.17 N :  3
# P-Value :  0.563371975193
# ********************
# Data :
#                      four  Average4   SD4
# 0  Normalized to B actin   TET2-PT7    SD
# 1                     air         1  0.08
# 2                  4l/min      1.02  0.16
# 3                  1l/min      0.91  0.09
# 4                0.5l/min      1.08  0.09
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 4l/min Mean :  1.02 SD :  0.16 N :  3
# P-Value :  0.855886729345
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 1l/min Mean :  0.91 SD :  0.09 N :  3
# P-Value :  0.265150254141
# ********************
# Air :  Mean :  1.0 SD :  0.08 N :  3
# 0.5l/min Mean :  1.08 SD :  0.09 N :  3
# P-Value :  0.31396040703
# ********************
# Data :
#                      four  Average4   SD4
# 0  Normalized to B actin   TET3-PT7    SD
# 1                     air      1.01  0.13
# 2                  4l/min      1.08   0.1
# 3                  1l/min      1.01  0.07
# 4                0.5l/min      1.06  0.04
# ********************
# Air :  Mean :  1.01 SD :  0.13 N :  3
# 4l/min Mean :  1.08 SD :  0.1 N :  3
# P-Value :  0.500795676769
# ********************
# Air :  Mean :  1.01 SD :  0.13 N :  3
# 1l/min Mean :  1.01 SD :  0.07 N :  3
# P-Value :  1.0
# ********************
# Air :  Mean :  1.01 SD :  0.13 N :  3
# 0.5l/min Mean :  1.06 SD :  0.04 N :  3
# P-Value :  0.558924871892
# ********************

# %%
dfH1 = pd.DataFrame(H1)
dfH2 = pd.DataFrame(H2)
dfH3 = pd.DataFrame(H3)
dfH4 = pd.DataFrame(H4)

# %%
dfH1
# Out:
#     ALU  CY1P1A1 DNMT1 DNMT3A DNMT3B HS 3 UTR HS 5 UTR  ORF1  ORF2  TET1  \
# 2  1.21  1487.71  0.97   1.04   1.09     1.08     1.01  1.18  1.18  1.44
# 3  0.87  9406.97   0.9   0.92   0.83     0.84     0.85  0.94  0.91  0.69
# 4  0.76   7993.7  0.69   0.64   0.52     0.63     0.58  0.67  0.67  0.21
#
#    TET2  TET3
# 2  0.98  0.92
# 3  0.86  0.86
# 4  0.64   0.8

# %%
dfH2
# Out:
#     ALU  CY1P1A1 DNMT1 DNMT3A DNMT3B HS 3 UTR HS 5 UTR  ORF1  ORF2  TET1  \
# 2   0.8    69.46  0.93   0.95   0.93     0.81     0.83  0.84  0.82  0.69
# 3  0.68   887.36  0.85   0.83   0.75     0.66      0.7  0.71   0.7  0.45
# 4   0.6  5465.07  0.89   0.88   0.86     0.57     0.56  0.56  0.57  0.35
#
#    TET2  TET3
# 2  0.89  1.03
# 3  0.78  0.85
# 4  0.82  0.78

# %%
dfH3
# Out:
#     ALU  CY1P1A1 DNMT1 DNMT3A DNMT3B HS 3 UTR HS 5 UTR  ORF1  ORF2  TET1  \
# 2  0.58     2.17  0.81   0.89   0.81     0.72     0.77  0.85  0.89  0.79
# 3  0.85   309.53  0.78   0.97   0.99     0.87     0.95  0.89  0.93  0.72
# 4  0.56  1496.78  0.72   0.94   0.92     0.67     0.73  0.71  0.77  0.47
#
#    TET2  TET3
# 2  0.87  0.98
# 3  0.92  0.94
# 4  0.85  0.98

# %%
dfH4
# Out:
#     ALU CY1P1A1 DNMT1 DNMT3A DNMT3B HS 3 UTR HS 5 UTR  ORF1  ORF2  TET1  TET2  \
# 2  0.93    0.93  0.97   1.08   1.04     1.07     1.06  1.11  1.08  0.99  1.02
# 3  0.94    2.26  0.83   0.99   0.94     0.94     0.97  0.93  1.03  0.93  0.91
# 4  0.77    5.05  0.85   1.09   0.86     0.88     0.89  0.81  0.96  0.93  1.08
#
#    TET3
# 2  1.08
# 3  1.01
# 4  1.06

# %%
#dfH1 = dfH1.drop([0]).copy()
#dfH3 = dfH3.drop([0]).copy()
#dfH5 = dfH5.drop([0]).copy()
#dfH7 = dfH7.drop([0]).copy()

# %%
df1 = dfH1.transpose()
df2 = dfH2.transpose()
df3 = dfH3.transpose()
df4 = dfH4.transpose()

# %%
df1.columns = ['4L/min','1L/min','0.5L/min']
df2.columns = ['4L/min','1L/min','0.5L/min']
df3.columns = ['4L/min','1L/min','0.5L/min']
df4.columns = ['4L/min','1L/min','0.5L/min']

# %%
df1['4L/min'] = pd.to_numeric(df1['4L/min'])
df1['1L/min'] = pd.to_numeric(df1['1L/min'])
df1['0.5L/min'] = pd.to_numeric(df1['0.5L/min'])



df2['4L/min'] = pd.to_numeric(df2['4L/min'])
df2['1L/min'] = pd.to_numeric(df2['1L/min'])
df2['0.5L/min'] = pd.to_numeric(df2['0.5L/min'])



df3['4L/min'] = pd.to_numeric(df3['4L/min'])
df3['1L/min'] = pd.to_numeric(df3['1L/min'])
df3['0.5L/min'] = pd.to_numeric(df3['0.5L/min'])



df4['4L/min'] = pd.to_numeric(df4['4L/min'])
df4['1L/min'] = pd.to_numeric(df4['1L/min'])
df4['0.5L/min'] = pd.to_numeric(df4['0.5L/min'])

# %%
df1.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df2.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df3.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df4.dtypes
# Out:
# 4L/min      float64
# 1L/min      float64
# 0.5L/min    float64
# dtype: object

# %%
df1 = df1.apply(lambda x: [y if y <=5 else 3 for y in x])
df2 = df2.apply(lambda x: [y if y <=5 else 3 for y in x])
df3 = df3.apply(lambda x: [y if y <=5 else 3 for y in x])
df4 = df4.apply(lambda x: [y if y <=5 else 3 for y in x])

# %%
df1
# Out:
#           4L/min  1L/min  0.5L/min
# ALU         1.21    0.87      0.76
# CY1P1A1     3.00    3.00      3.00
# DNMT1       0.97    0.90      0.69
# DNMT3A      1.04    0.92      0.64
# DNMT3B      1.09    0.83      0.52
# HS 3 UTR    1.08    0.84      0.63
# HS 5 UTR    1.01    0.85      0.58
# ORF1        1.18    0.94      0.67
# ORF2        1.18    0.91      0.67
# TET1        1.44    0.69      0.21
# TET2        0.98    0.86      0.64
# TET3        0.92    0.86      0.80

# %%
df1 = df1.reindex(["CY1P1A1", "ALU", "HS 5 UTR","HS 3 UTR","ORF1","ORF2","DNMT1","DNMT3A","DNMT3B","TET1","TET2","TET3"])

# %%
df1
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     3.00    3.00      3.00
# ALU         1.21    0.87      0.76
# HS 5 UTR    1.01    0.85      0.58
# HS 3 UTR    1.08    0.84      0.63
# ORF1        1.18    0.94      0.67
# ORF2        1.18    0.91      0.67
# DNMT1       0.97    0.90      0.69
# DNMT3A      1.04    0.92      0.64
# DNMT3B      1.09    0.83      0.52
# TET1        1.44    0.69      0.21
# TET2        0.98    0.86      0.64
# TET3        0.92    0.86      0.80

# %%
df2 = df2.reindex(["CY1P1A1", "ALU", "HS 5 UTR","HS 3 UTR","ORF1","ORF2","DNMT1","DNMT3A","DNMT3B","TET1","TET2","TET3"])

# %%
df2
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     3.00    3.00      3.00
# ALU         0.80    0.68      0.60
# HS 5 UTR    0.83    0.70      0.56
# HS 3 UTR    0.81    0.66      0.57
# ORF1        0.84    0.71      0.56
# ORF2        0.82    0.70      0.57
# DNMT1       0.93    0.85      0.89
# DNMT3A      0.95    0.83      0.88
# DNMT3B      0.93    0.75      0.86
# TET1        0.69    0.45      0.35
# TET2        0.89    0.78      0.82
# TET3        1.03    0.85      0.78

# %%
df3 = df3.reindex(["CY1P1A1", "ALU", "HS 5 UTR","HS 3 UTR","ORF1","ORF2","DNMT1","DNMT3A","DNMT3B","TET1","TET2","TET3"])

# %%
df3
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     2.17    3.00      3.00
# ALU         0.58    0.85      0.56
# HS 5 UTR    0.77    0.95      0.73
# HS 3 UTR    0.72    0.87      0.67
# ORF1        0.85    0.89      0.71
# ORF2        0.89    0.93      0.77
# DNMT1       0.81    0.78      0.72
# DNMT3A      0.89    0.97      0.94
# DNMT3B      0.81    0.99      0.92
# TET1        0.79    0.72      0.47
# TET2        0.87    0.92      0.85
# TET3        0.98    0.94      0.98

# %%
df4 = df4.reindex(["CY1P1A1", "ALU", "HS 5 UTR","HS 3 UTR","ORF1","ORF2","DNMT1","DNMT3A","DNMT3B","TET1","TET2","TET3"])

# %%
df4
# Out:
#           4L/min  1L/min  0.5L/min
# CY1P1A1     0.93    2.26      3.00
# ALU         0.93    0.94      0.77
# HS 5 UTR    1.06    0.97      0.89
# HS 3 UTR    1.07    0.94      0.88
# ORF1        1.11    0.93      0.81
# ORF2        1.08    1.03      0.96
# DNMT1       0.97    0.83      0.85
# DNMT3A      1.08    0.99      1.09
# DNMT3B      1.04    0.94      0.86
# TET1        0.99    0.93      0.93
# TET2        1.02    0.91      1.08
# TET3        1.08    1.01      1.06

# %%
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df1,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("T0")
plt.yticks(rotation=0)
fig.savefig(result_path + "B_actin/T0.png")

# %%
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df2,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("T1")
plt.yticks(rotation=0)
fig.savefig(result_path + "B_actin/T1.png")

# %%
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df3,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("PT2")
plt.yticks(rotation=0)
fig.savefig(result_path + "B_actin/PT2.png")

# %%
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
pal = sns.dark_palette("navy", as_cmap=True)
sns.heatmap(df4,cmap="YlGnBu",square=True,cbar_kws=dict(ticks=[0.0,0.2,0.3,0.5,0.8, 1.0,1.5,2.0,2.5,3,3.5,4.0,4.5,5])).set_title("PT7")
plt.yticks(rotation=0)
fig.savefig(result_path + "B_actin/PT7.png")
